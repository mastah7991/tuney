# %% [markdown]
# # AUDIO

# %% [markdown]
# Your task is to swap the 'phases' between two sounds.
#
# Use the inverse Fourier transform for this, e.g.`np.fft.ifft`

# %%
import numpy as np
import scipy.io.wavfile as wav
import IPython

fs, audio1 = wav.read('audio1.wav') 
fs, audio2 = wav.read('audio2.wav') 

# Perform Fourier Transform on both signals
fft_audio1 = np.fft.fft(audio1)
fft_audio2 = np.fft.fft(audio2)

# Separate magnitude and phase components
mag_audio1 = np.abs(fft_audio1)
phase_audio1 = np.angle(fft_audio1)

mag_audio2 = np.abs(fft_audio2)
phase_audio2 = np.angle(fft_audio2)

# %%
print("loud sounds!")
IPython.display.display(IPython.display.Audio("audio1.wav"))
IPython.display.display(IPython.display.Audio("audio2.wav"))
# Out:
# loud sounds!
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# YOUR IMPLEMENTATION HERE

# %%
wav.write('modified_audio1.wav', fs, modified_audio1)
wav.write('modified_audio2.wav', fs, modified_audio2)

# %%
IPython.display.display(IPython.display.Audio("modified_audio1.wav"))
IPython.display.display(IPython.display.Audio("modified_audio2.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
